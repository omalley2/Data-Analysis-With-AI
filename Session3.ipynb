# %% [markdown]
# # Session #3: Data Structures, List Comprehensions, Error Handling & File I/O
#
# ## 1. 🚀 Recap & Objectives
#
# In this session you will:
# - Explore Python’s core data structures in depth
# - Master list, dict, and set comprehensions
# - Learn robust error handling with try/except/finally
# - Perform file input/output for text and CSV files
# - Extend your Data Profiler to handle exceptions and read/write files
#
# ## 2. 🐍 Advanced Data Structures
#
# We’ll work with lists, tuples, sets, and dictionaries. Notice when each structure is most appropriate.

# %%
# Lists: ordered, mutable
fruits = ["apple", "banana", "cherry"]
fruits.append("date")
print("Fruits:", fruits)

# Tuples: ordered, immutable
coordinates = (10.5, 20.3)
print("Coordinates:", coordinates)

# Sets: unordered, unique
colors = {"red", "green", "blue", "red"}
print("Unique colors:", colors)

# Dictionaries: key→value mapping
person = {"name": "Alice", "age": 30}
person["city"] = "Seattle"
print("Person record:", person)
# Out:
# Fruits: ['apple', 'banana', 'cherry', 'date']
# Coordinates: (10.5, 20.3)
# Unique colors: {'blue', 'red', 'green'}
# Person record: {'name': 'Alice', 'age': 30, 'city': 'Seattle'}

# %%
person = {"name": "Alice", "age": 30}
person
# Out:
# {'name': 'Alice', 'age': 30}

# %%
person["city"] = "Seattle"
person
# Out:
# {'name': 'Alice', 'age': 30, 'city': 'Seattle'}

# %%
import pandas as pd

person1 = {'name': 'Steve', 'age': 40, 'city': 'Chicago'}
my_list = [person, person1]
pd.DataFrame(my_list).sort_values('city')
# Out:
#     name  age     city
# 1  Steve   40  Chicago
# 0  Alice   30  Seattle

# %%
my_set = set(['cherry', 'apple', 'banana', 'apple'])
sorted(my_set)
# Out:
# ['apple', 'banana', 'cherry']

# %%
set(['apple', 'banana', 'apple', 'cherry'])
# Out:
# {'apple', 'banana', 'cherry'}

# %%
fruits = ['apple', 'banana', 'apple', 'cherry']

for fruit in fruits:
  print('I like', fruit)
# Out:
# I like apple
# I like banana
# I like apple
# I like cherry

# %%
for fruit in set(fruits):
  print('I like', fruit)
# Out:
# I like cherry
# I like banana
# I like apple

# %%
# lists are mutable
fruits[0] = 'pineapple'
fruits
# Out:
# ['pineapple', 'banana', 'cherry', 'date']

# %%
# tuples are not mutable

coordinates[0] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4189050341.py in <cell line: 0>()
#       1 # tuples are not mutable
#       2
# ----> 3 coordinates[0] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### Practice
#
# 1. Create a tuple of your three favorite movies.
# 2. Build a set of five random integers, then add and remove one.
# 3. Create a dict mapping course topics → duration (in hours).

# %%
# Create a tuple of your three favorite movies.
movies = ('Toy Story', 'Monsters inc', 'A bugs life')
movies_list = list(movies)
movies_list[0] = 'Toy Story 2'
movies = tuple(movies_list)
movies
# Out:
# ('Toy Story 2', 'Monsters inc', 'A bugs life')

# %%
# Build a set of five random integers, then add and remove one.

import numpy as np

rand_num = np.random.randint(0,100, size=5)
my_set = set(rand_num)
my_set.add(150)

# %%
my_set
# Out:
# {np.int64(6), np.int64(33), np.int64(43), np.int64(45), np.int64(74), 150}

# %%
removed_value = my_set.pop()

# %%
removed_value
# Out:
# np.int64(33)

# %%
my_set
# Out:
# {np.int64(6), np.int64(43), np.int64(45), np.int64(74), 150}

# %% [markdown]
# ## 3. 🔍 Comprehensions: List, Dict & Set
#
# Comprehensions offer a concise, expressive way to build collections.

# %%
# List comprehension: squares of even numbers 0–10
squares = [x**2 for x in range(11) if x % 2 == 0]
print("Even squares:", squares)

# Dict comprehension: map number → its cube
cubes = {x: x**3 for x in range(6)}
print("Cubes:", cubes)

# Set comprehension: unique first letters of words
words = ["apple", "banana", "cherry", "avocado"]
first_letters = {w[0] for w in words}
print("First letters:", first_letters)
# Out:
# Even squares: [0, 4, 16, 36, 64, 100]
# Cubes: {0: 0, 1: 1, 2: 8, 3: 27, 4: 64, 5: 125}
# First letters: {'b', 'a', 'c'}

# %% [markdown]
# ### Challenge
#
# Using a single comprehension, generate all two-letter uppercase strings from 'A'–'Z' (e.g., 'AA', 'AB', …).

# %%
import string

string.ascii_uppercase
# Out:
# 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
alphabet = string.ascii_uppercase

output_list = []
for x in alphabet:
  for y in alphabet:
    output_list.append(x+y)
#output_list

# %%
res = [x + y for x in alphabet for y in alphabet]

# %% [markdown]
# ## 4. 🛡️ Error Handling
#
# Make your code robust by catching and handling exceptions.
#
# #### 1. Explaining try/except/else
#
# When you wrap code in a `try` block, you tell Python to attempt an operation and handle specific errors gracefully:
#
# - `try`: code that might raise an exception
# - `except`: one or more clauses that catch and handle particular exceptions
# - `else`: runs only if no exception was raised, often used to return the successful result
#
# ```python
# def safe_divide(a, b):
#     try:
#         result = a / b
#     except ZeroDivisionError:
#         print("Error: Division by zero.")
#         return None
#     except TypeError:
#         print("Error: Unsupported operand types.")
#         return None
#     else:
#         return result

# %%
def safe_divide(a, b):
    try:
        result = a / b
    except ZeroDivisionError:
        print("Error: Division by zero.")
        return None
    except TypeError:
        print("Error: Unsupported operand types.")
        return None
    else:
        return result

# %%
def safe_divide2(a, b):
  try:
    result = a/b
    return result
  except:
    print('Error')
    return None

# %%
my_list = [1, 2, 0, '5', 2, 5, 6]

for num in my_list:
  print(safe_divide2(10, num))
# Out:
# 10.0
# 5.0
# Error
# None
# Error
# None
# 5.0
# 2.0
# 1.6666666666666667

# %%
safe_divide2(5, 0)
# Out:
# Error

# %%
safe_divide(5, 1)
# Out:
# 5.0

# %%
my_list = [1, 2, 0, '5', 2, 5, 6]

for num in my_list:
  print(safe_divide(10, num))
# Out:
# 10.0
# 5.0
# Error: Division by zero.
# None
# Error: Unsupported operand types.
# None
# 5.0
# 2.0
# 1.6666666666666667

# %%
def divide(a, b):
  return a/b
divide(5, '5')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2006573233.py in <cell line: 0>()
#       1 def divide(a, b):
#       2   return a/b
# ----> 3 divide(5, '5')
#
# /tmp/ipython-input-2006573233.py in divide(a, b)
#       1 def divide(a, b):
# ----> 2   return a/b
#       3 divide(5, '5')
#
# TypeError: unsupported operand type(s) for /: 'int' and 'str'

# %%
my_list = [1, 2, 0, '5', 2, 5, 6]

for num in my_list:
  print(divide(10, num))
# Out:
# 10.0
# 5.0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-3717786849.py in <cell line: 0>()
#       2
#       3 for num in my_list:
# ----> 4   print(divide(10, num))
#
# /tmp/ipython-input-2006573233.py in divide(a, b)
#       1 def divide(a, b):
# ----> 2   return a/b
#       3 divide(5, '5')
#
# ZeroDivisionError: division by zero

# %%
# A finally block executes no matter what happened in try or except.
# It’s ideal for cleanup or logging actions that must always run:

def safe_divide(a, b):
    try:
        result = a / b
        #print(a, b)
        print("safe_divide called with:", a, b)
        return result
    except ZeroDivisionError:
        print("Error: Division by zero.")
        return None
    except TypeError:
        print("Error: Unsupported operand types.")
        return None
    else:
        return result
    finally:
        print('Finally Block', a, b)

# Demonstration
print(safe_divide(10, 2))   # Logs call, then prints 5.0
print(safe_divide(5, 0))    # Logs call, prints error message, then None
# Out:
# safe_divide called with: 10 2
# Finally Block 10 2
# 5.0
# Error: Division by zero.
# Finally Block 5 0
# None

# %%
1/ 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-2564180224.py in <cell line: 0>()
# ----> 1 1/ 0
#
# ZeroDivisionError: division by zero

# %%
safe_divide(5, 1)
# Out:
# safe_divide called with: 5 1
# Finally Block 5 1
# 5.0

# %% [markdown]
# ## 4.1 Practice
#
# 1. Write a function that reads an index `i` from a list and handles out-of-range errors gracefully.
# 2. Create and raise a custom exception when a passed value is negative.

# %%
my_list = [1, 2, 3]
my_list[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-3123617771.py in <cell line: 0>()
#       1 my_list = [1, 2, 3]
# ----> 2 my_list[3]
#
# IndexError: list index out of range

# %%
# Write a function that reads an index i from a list and
# handles out-of-range errors gracefully.

def read_index(list, i, default=None):
  try:
    result = list[i]
  except IndexError:
    print(f"Error: Index {i} out of range for list of length {len(list)}")
    return default
  else:
    return result

# %%
read_index([1,2], 3, default='')
# Out:
# Error: Index 3 out of range for list of length 2
# ''

# %%
# Create and raise a custom exception when a passed value is negative.
def require_non_negative(num):
  if num < 0:
    raise ValueError(f'Number cannot be negative. Number was {num}')
  return num

# %%
require_non_negative(-99)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-816549018.py in <cell line: 0>()
# ----> 1 require_non_negative(-99)
#
# /tmp/ipython-input-2331960610.py in require_non_negative(num)
#       2 def require_non_negative(num):
#       3   if num < 0:
# ----> 4     raise ValueError(f'Number cannot be negative. Number was {num}')
#       5   return num
#
# ValueError: Number cannot be negative. Number was -99

# %%
def index_reader(list, i):
  if i < 0:
    raise ValueError("Positive numbers only")
  try:
    result = list[i]
    return result
  except IndexError:
    print("Requested item is outside of index length")
    return None
  finally:
    print("Done")

# %%
index_reader([1, 2, 3], 2)
# Out:
# Done
# 3

# %% [markdown]
# ## 5. 💾 File I/O: Text & CSV
#
# Learn to read from and write to files using context managers.

# %%
# Text file I/O
text_path = "sample_2.txt"
with open(text_path, "w") as f:
    f.write("Line 1\nLine 2\nLine 3\n")

# %%
with open(text_path, "r") as f:
    for line in f:
        print("Read:", line.strip())
# Out:
# Read: Line 1
# Read: Line 2
# Read: Line 3

# %%
# CSV file I/O with csv module
import csv

# %%
csv_path = "sample.csv"
rows = [
    ["name", "age", "city"],
    ["Alice", 30, "Seattle"],
    ["Bob", 25, "Denver"],
]

# %%
with open(csv_path, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(rows)

# %%
with open(csv_path, "r") as f:
    reader = csv.DictReader(f)
    for row in reader:
        print(row)
# Out:
# {'name': 'Alice', 'age': '30', 'city': 'Seattle'}
# {'name': 'Bob', 'age': '25', 'city': 'Denver'}

# %%
rows
# Out:
# [['name', 'age', 'city'], ['Alice', 30, 'Seattle'], ['Bob', 25, 'Denver']]

# %%
import pandas as pd

df = pd.DataFrame(rows[1:], columns=rows[0])
df
# Out:
#     name  age     city
# 0  Alice   30  Seattle
# 1    Bob   25   Denver

# %%
df.set_index('name', inplace=True)
df
# Out:
#        age     city
# name
# Alice   30  Seattle
# Bob     25   Denver

# %%
# saving dataframe as csv
df.to_csv('sample_data.csv', index=True)

# %%
# load in a csv into a pandas dataframe
df_new = pd.read_csv('sample_data.csv')
df_new
# Out:
#     name  age     city
# 0  Alice   30  Seattle
# 1    Bob   25   Denver

# %% [markdown]
# ## 5.1 Practice
#
# 1. Write code to append a new row to `sample.csv`.
# 2. Read `sample.csv` and filter rows where age > 28.

# %%
csv_path = "sample.csv"
new_row = ["Charlie", 32, "London"]
with open(csv_path, "a", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(new_row)

# %%
with open(csv_path, 'r') as f:
  reader = csv.DictReader(f)
  for row in reader:
    print(row['name'])
# Out:
# Alice
# Bob
# Charlie

# %%
with open(csv_path, 'r') as f:
  reader = csv.DictReader(f)
  for row in reader:
    if int(row["age"]) > 28:
        print(row)
# Out:
# {'name': 'Alice', 'age': '30', 'city': 'Seattle'}
# {'name': 'Charlie', 'age': '32', 'city': 'London'}

# %%
# add row using pandas

sample_data = pd.read_csv('sample_data.csv')
sample_data
# Out:
#     name  age     city
# 0  Alice   30  Seattle
# 1    Bob   25   Denver

# %%
new_row = pd.DataFrame({'name': ['Steve'], 'age': [45],
                        'city': ['NYC']})
new_row
# Out:
#     name  age city
# 0  Steve   45  NYC

# %%
df_final = pd.concat([sample_data, new_row], ignore_index=True)
df_final
# Out:
#     name  age     city
# 0  Alice   30  Seattle
# 1    Bob   25   Denver
# 2  Steve   45      NYC

# %%
df_final[df_final['age'] > 28]
# Out:
#     name  age     city   even
# 0   Ally   30  Seattle   True
# 2  Steve   45      NYC  False

# %%
df_final.loc[1, 'name'] = 'Rob'
df_final
# Out:
#     name  age     city
# 0  Alice   30  Seattle
# 1    Rob   25   Denver
# 2  Steve   45      NYC

# %%
df_final.reset_index(inplace=True)
df_final
# Out:
#     name  age     city
# 0   Ally   30  Seattle
# 1    Rob   25   Denver
# 2  Steve   45      NYC

# %%
# check if age is even
df_final['even'] = False

for x in range(len(df_final)):
  if df_final.loc[x, 'age'] % 2 == 0:
    df_final.loc[x, 'even'] = True
  else:
    df_final.loc[x, 'even'] = False
#df_final

# %%
# check if age is even
df_final['even'] = False

for x in range(len(df_final)):
  if df_final.iloc[x, 1] % 2 == 0:
    df_final.iloc[x, 3] = True
  else:
    df_final.iloc[x, 3] = False
df_final

# %%
df_final.loc[0, 'name'] = 'Ally'

# %%
df_final.set_index('name', inplace=True)
df_final
# Out:
#        age     city
# name
# Ally    30  Seattle
# Rob     25   Denver
# Steve   45      NYC

# %%
df_final.iloc[1, 0]
# Out:
# np.int64(25)

# %%
df_final.loc['Rob', 'age']
# Out:
# np.int64(25)

# %%
# grab what city Steve is from using loc
df_final.loc['Steve', 'city']
# Out:
# 'NYC'

# %%
df_final
# Out:
#     name  age     city   even
# 0   Ally   30  Seattle   True
# 1    Rob   25   Denver  False
# 2  Steve   45      NYC  False

# %%
# grab what city Steve is from using iloc
assert df_final.columns[2] == 'city'
df_final.iloc[2, 2]
# Out:
# 'NYC'

# %%
df_final
# Out:
#        age     city
# name
# Ally    30  Seattle
# Rob     25   Denver
# Steve   45      NYC

# %%
df_final['age'].iloc[0:2]
# Out:
# name
# Ally    30
# Rob     25
# Name: age, dtype: int64

# %% [markdown]
# ## 6. 🛠️ Mini Project: Robust Data Profiler
#
# Extend your Data Profiler to:
# - Accept a file path as input
# - Handle file-not-found and parse errors
# - Read/write CSV and text summary

# %%
file_path = 'jeff.csv'

df = pd.read_csv(file_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2653512679.py in <cell line: 0>()
#       1 file_path = 'jeff.csv'
#       2
# ----> 3 df = pd.read_csv(file_path)
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'jeff.csv'

# %%
dict((x, x**3) for x in range(4))
# Out:
# {0: 0, 1: 1, 2: 8, 3: 27}

# %%
map(lambda x: x**3, range(5))
